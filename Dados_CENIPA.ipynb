# %% [markdown]
# ### Análise de Dados de Ocorrências Aeronática do CENIPA

# %%
# Importar bibliotecas
import pandas as pd

data = pd.read_csv("ocorrencias_aviacao.csv", index_col='codigo_ocorrencia')

data.head(10)
# Out:
#                   ocorrencia_classificacao  \
# codigo_ocorrencia
# 201305055424986                   ACIDENTE
# 201605160250139            INCIDENTE GRAVE
# 201805021421302                  INCIDENTE
# 201311259977425            INCIDENTE GRAVE
# 201103187273112                  INCIDENTE
# 200808073991179                   ACIDENTE
# 201108118145873                   ACIDENTE
# 201604251335501            INCIDENTE GRAVE
# 201604062021424                   ACIDENTE
# 200902274965349                  INCIDENTE
#
#                                                      ocorrencia_tipo  \
# codigo_ocorrencia
# 201305055424986                                FALHA DO MOTOR EM VOO
# 201605160250139    COLISÃO COM OBSTÁCULO DURANTE A DECOLAGEM E POUSO
# 201805021421302                                            AERÓDROMO
# 201311259977425                                       POUSO SEM TREM
# 201103187273112                                               OUTROS
# ...

# %%
columns = {
    'ocorrencia_latitude':'latitude',
    'ocorrencia_longitude':'longitude',
    'ocorrencia_dia':'data',
    'ocorrencia_classificacao':'classificacao',
    'ocorrencia_tipo':'tipo',
    'ocorrencia_tipo_categoria':'tipo_categoria',
    'ocorrencia_tipo_icao':'tipo_icao',
    'ocorrencia_aerodromo':'aerodromo',
    'ocorrencia_cidade':'cidade',
    'investigacao_status':'status',
    'divulgacao_relatorio_numero':'relatorio_numero',
    'total_aeronaves_envolvidas':'aeronaves_envolvidas'
}

# %%
data = data.rename(columns=columns)
data.head()
# Out:
#                      classificacao  \
# codigo_ocorrencia
# 201305055424986           ACIDENTE
# 201605160250139    INCIDENTE GRAVE
# 201805021421302          INCIDENTE
# 201311259977425    INCIDENTE GRAVE
# 201103187273112          INCIDENTE
#
#                                                                 tipo  \
# codigo_ocorrencia
# 201305055424986                                FALHA DO MOTOR EM VOO
# 201605160250139    COLISÃO COM OBSTÁCULO DURANTE A DECOLAGEM E POUSO
# 201805021421302                                            AERÓDROMO
# 201311259977425                                       POUSO SEM TREM
# 201103187273112                                               OUTROS
#
#                                                       tipo_categoria  \
# codigo_ocorrencia
# 201305055424986                  FALHA OU MAU FUNCIONAMENTO DO MOTOR
# 201605160250139    COLISÃO COM OBSTÁCULO DURANTE A DECOLAGEM E POUSO
# ...

# %%
data.data
# Out:
# codigo_ocorrencia
# 201305055424986    2013-05-05
# 201605160250139    2016-05-13
# 201805021421302    2018-03-09
# 201311259977425    2013-11-25
# 201103187273112    2011-03-18
#                       ...
# 200811264169752    2008-11-26
# 200910311058203    2009-10-31
# 200810318709738    2008-10-31
# 200803063018556    2008-03-06
# 201309012098180    2013-09-02
# Name: data, Length: 5208, dtype: object

# %%
#Concatenar data e hora
data.data = data.data + " " + data.ocorrencia_horario
data.data =pd.to_datetime(data.data)

#ver conversão
data.data
# Out:
# codigo_ocorrencia
# 201305055424986   2013-05-05 11:00:00
# 201605160250139   2016-05-13 19:19:00
# 201805021421302   2018-03-09 22:40:00
# 201311259977425   2013-11-25 12:32:00
# 201103187273112   2011-03-18 13:30:00
#                           ...
# 200811264169752   2008-11-26 16:40:00
# 200910311058203   2009-10-31 12:10:00
# 200810318709738   2008-10-31 18:00:00
# 200803063018556   2008-03-06 07:55:00
# 201309012098180   2013-09-02 02:54:00
# Name: data, Length: 5208, dtype: datetime64[ns]

# %%
data.head()
# Out:
#                      classificacao  \
# codigo_ocorrencia
# 201305055424986           ACIDENTE
# 201605160250139    INCIDENTE GRAVE
# 201805021421302          INCIDENTE
# 201311259977425    INCIDENTE GRAVE
# 201103187273112          INCIDENTE
#
#                                                                 tipo  \
# codigo_ocorrencia
# 201305055424986                                FALHA DO MOTOR EM VOO
# 201605160250139    COLISÃO COM OBSTÁCULO DURANTE A DECOLAGEM E POUSO
# 201805021421302                                            AERÓDROMO
# 201311259977425                                       POUSO SEM TREM
# 201103187273112                                               OUTROS
#
#                                                       tipo_categoria  \
# codigo_ocorrencia
# 201305055424986                  FALHA OU MAU FUNCIONAMENTO DO MOTOR
# 201605160250139    COLISÃO COM OBSTÁCULO DURANTE A DECOLAGEM E POUSO
# ...

# %% [markdown]
# Selecionar apenas as colunas que serão usadas no app do Streamlit (será o retorno da função load_data())

# %%
data[list(columns.values())]
# Out:
#                    latitude  longitude                data    classificacao  \
# codigo_ocorrencia
# 201305055424986     -9.9085   -63.0333 2013-05-05 11:00:00         ACIDENTE
# 201605160250139    -11.2644   -61.2589 2016-05-13 19:19:00  INCIDENTE GRAVE
# 201805021421302    -11.4956   -61.4508 2018-03-09 22:40:00        INCIDENTE
# 201311259977425    -11.4956   -61.4508 2013-11-25 12:32:00  INCIDENTE GRAVE
# 201103187273112    -13.1950   -60.8184 2011-03-18 13:30:00        INCIDENTE
# ...                     ...        ...                 ...              ...
# 200811264169752      0.0000     0.0000 2008-11-26 16:40:00        INCIDENTE
# 200910311058203      0.0000     0.0000 2009-10-31 12:10:00        INCIDENTE
# 200810318709738      0.0000     0.0000 2008-10-31 18:00:00        INCIDENTE
# 200803063018556      0.0000     0.0000 2008-03-06 07:55:00        INCIDENTE
# 201309012098180      6.7119   -32.9919 2013-09-02 02:54:00         ACIDENTE
#
# ...

# %%
data.classificacao.unique().tolist()
# Out:
# ['ACIDENTE', 'INCIDENTE GRAVE', 'INCIDENTE']

# %%
data[(data.data.dt.year == 2017) & (data.classificacao.isin(['ACIDENTE']))]
# Out:
#                   classificacao                                       tipo  \
# codigo_ocorrencia
# 201711152026161        ACIDENTE                             POUSO SEM TREM
# 201706241353561        ACIDENTE  CAUSADO POR FENÔMENO METEOROLÓGICO EM VOO
# 201710191757029        ACIDENTE                      FALHA DO MOTOR EM VOO
# 201707050515445        ACIDENTE                      FALHA DO MOTOR EM VOO
# 201706152048494        ACIDENTE                      FALHA DO MOTOR EM VOO
# ...                         ...                                        ...
# 201704031537231        ACIDENTE                              INDETERMINADO
# 201711271331205        ACIDENTE                          EXCURSÃO DE PISTA
# 201707061920096        ACIDENTE                                POUSO LONGO
# 201709121317043        ACIDENTE                   PERDA DE CONTROLE EM VOO
# 201704150134378        ACIDENTE                  PERDA DE CONTROLE NO SOLO
#
# ...

# %%
data.shape
# Out:
# (5208, 21)
